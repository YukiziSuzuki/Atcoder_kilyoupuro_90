# %% [markdown]
# ![スクリーンショット 2023-11-17 150351.png](data:image/png;base64,...)

# %% [markdown]
# ![スクリーンショット 2023-11-17 150432.png](data:image/png;base64,...)

# %%
n = int(input())
a=list(map(int,input().split()))
b=list(map(int,input().split()))

a.sort()
b.sort()

score = 0

for i in range(n):
    score += abs(a[i]-b[i])

print(score)
